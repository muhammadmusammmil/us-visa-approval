# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\musammil\Desktop\dataset_csv\payment_fraud.csv")
df.head()
# Out:
#    accountAgeDays  numItems  localTime paymentMethod  paymentMethodAgeDays  \
# 0              29         1   4.745402        paypal             28.204861
# 1             725         1   4.742303   storecredit              0.000000
# 2             845         1   4.921318    creditcard              0.000000
# 3             503         1   4.886641    creditcard              0.000000
# 4            2000         1   5.040929    creditcard              0.000000
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df.isnull().sum()
# Out:
# accountAgeDays          0
# numItems                0
# localTime               0
# paymentMethod           0
# paymentMethodAgeDays    0
# label                   0
# dtype: int64

# %%
df['label'].value_counts().plot(kind="bar", color=["red", "green"])
# Out:
# <Axes: xlabel='label'>

# %% [markdown]
# Inbalance dataset

# %%
df['paymentMethod'].value_counts()
# Out:
# paymentMethod
# creditcard     28004
# paypal          9303
# storecredit     1914
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 10))

for i, col in enumerate(df, 1):
    plt.subplot(3, 2, i)
    df[df['label'] == 0][col].hist(bins=35, color='blue', alpha=0.6)
    df[df['label'] == 1][col].hist(bins=35, color='red', alpha=0.6)
    plt.legend()
    plt.xlabel(col)
# Out:
# C:\Users\musammil\AppData\Local\Temp\ipykernel_4964\170303664.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
